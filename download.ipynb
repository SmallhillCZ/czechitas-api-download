# %% [markdown]
# # Ukázka stažení dat z API pro DA jaro 2022

# %% [markdown]
# ### Načtení knihoven

# %%
# nactu knihovnu pandas
import pandas as pd

# %% [markdown]
# ### Stažení dat

# %%
# ulozim adresu API
endpoint = 'https://opendata.mfcr.cz/api/v1/faktury'

offset = 0 # od ktereho radku zacit
limit = 1000 # kolik radku na cyklus

# nactu si prazdny dataframe
df = pd.DataFrame()

# budu opakovat dokud nezavolam break
while True:

  # vytvorim adresu podle dokumentace - limit je kolik radku, offset od ktereho a `dodavatel_i%C4%8Do=eq.64949681` je filtr na dodavatele T-Mobile
  # pismenko f pred uvozovkami mi dovoli vyplnovat do textu hodnoty promennych jako `{nazev_promenne}`
  # treba pro prvni cyklus bude vysledek takovy: https://opendata.mfcr.cz/api/v1/faktury?limit=1000&offset=0&dodavatel_i%C4%8Do=eq.64949681
  url = f"{endpoint}?limit={limit}&offset={offset}&dodavatel_i%C4%8Do=eq.64949681"
  
  print(url) # vypisu url na obrazovku

  # nactu data
  df_part = pd.read_json(url)

  # zapsat data do celkoveho df - sloucim stare a nove zaznamy a ulozim je do puvodni promenne df
  df = pd.concat([df, df_part])

  # pocet radku tenhle iterace
  count = len(df_part)
  print(f"Pocet radku: {count}") # vypisu pocet radku na obrazovku

  # zvysim offset o pocet radku abychom pristi cyklus zacinali od dalsiho radku
  offset += count

  # pokud se v tomto cyklu nestahly zadne radky, koncim cyklus prikazem `break`
  if count == 0:
    break

# vypisu prvnich pet radku pro kontrolu
df.head()
# Out:
# https://opendata.mfcr.cz/api/v1/faktury?limit=10000&offset=0&dodavatel_i%C4%8Do=eq.64949681
# Pocet radku: 1000
# https://opendata.mfcr.cz/api/v1/faktury?limit=10000&offset=1000&dodavatel_i%C4%8Do=eq.64949681
# Pocet radku: 967
# https://opendata.mfcr.cz/api/v1/faktury?limit=10000&offset=1967&dodavatel_i%C4%8Do=eq.64949681
# Pocet radku: 0
#   typ_záznamu                                                iri  \
# 0    souhrnný    https://opendata.mfcr.cz/lod/faktury/2100003203
# 1   položkový  https://opendata.mfcr.cz/lod/faktury/210000320...
# 2    souhrnný    https://opendata.mfcr.cz/lod/faktury/2100003204
# 3   položkový  https://opendata.mfcr.cz/lod/faktury/210000320...
# 4    souhrnný    https://opendata.mfcr.cz/lod/faktury/2100003172
#
#    dodavatel_ičo               dodavatel_název typ_dokladu     částka  \
# 0       64949681  T-Mobile Czech Republic a.s.           F  276791.61
# 1       64949681  T-Mobile Czech Republic a.s.           F  276791.61
# 2       64949681  T-Mobile Czech Republic a.s.           F   85071.63
# 3       64949681  T-Mobile Czech Republic a.s.           F   85071.63
# 4       64949681  T-Mobile Czech Republic a.s.           F   15609.00
#
#    částka_bez_dph  částka_v_měně měna datum_vystavení datum_přijetí  \
# 0       276791.61      276791.61  CZK      2021-11-01    2021-11-03
# 1       276791.61      276791.61  CZK      2021-11-01    2021-11-03
# 2        85071.63       85071.63  CZK      2021-11-01    2021-11-03
# 3        85071.63       85071.63  CZK      2021-11-01    2021-11-03
# 4        15609.00       15609.00  CZK      2021-10-06    2021-11-02
#
#   datum_splatnosti datum_úhrady  částka_k_úhradě  částka_k_úhradě_v_měně  \
# 0       2021-12-01   2021-11-26        276791.61               276791.61
# 1       2021-12-01   2021-11-26        276791.61               276791.61
# 2       2021-12-01   2021-11-26         85071.63                85071.63
# 3       2021-12-01   2021-11-26         85071.63                85071.63
# 4       2021-11-08   2021-11-05         15609.00                15609.00
#
#                                          účel_platby  položka_rozpočtu  \
# 0  Mobilní hlasové a datové telekomunikační služb...               NaN
# 1  Mobilní hlasové a datové telekomunikační služb...            5162.0
# 2  Mobilní hlasové a datové telekomunikační služb...               NaN
# 3  Mobilní hlasové a datové telekomunikační služb...            5162.0
# 4  Datové služby Dark Fibre pro MF lokalita Cihel...               NaN
#
#              název_položky_rozpočtu  částka_za_položku_rozpočtu  číslo_faktury
# 0                              None                         NaN     2100003203
# 1  Služby elektronických komunikací                   276791.61     2100003203
# 2                              None                         NaN     2100003204
# 3  Služby elektronických komunikací                    85071.63     2100003204
# 4                              None                         NaN     2100003172

# %% [markdown]
# ### Uložení dat do CSV

# %%
df.to_csv("./download.csv", index=False) # index=False zajistí, že se neuloží první sloupec s čísly řádků
